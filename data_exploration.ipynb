# %%
import pandas as pd

# %%
cities = pd.read_csv('2020_Full_Cities_Dataset.csv')
cities.head()
# Out:
#    Unnamed: 0 Questionnaire  Year Reported to CDP  Account Number  \
# 0           0   Cities 2020                  2020           68296
# 1           1   Cities 2020                  2020            8242
# 2           2   Cities 2020                  2020           73301
# 3           3   Cities 2020                  2020           54488
# 4           4   Cities 2020                  2020           54696
#
#                  Organization                   Country  \
# 0    Hobsons Bay City Council                 Australia
# 1            City of Helsinki                   Finland
# 2          City of Gretna, LA  United States of America
# 3      Trondheim Municipality                    Norway
# 4  XIV Ayuntamiento de La Paz                    Mexico
#
#                    CDP Region       Parent Section  \
# 0  Southeast Asia and Oceania                  NaN
# 1                      Europe  City-wide Emissions
# 2               North America        Opportunities
# ...

# %%
cities['Section'].value_counts(normalize=True)
# Out:
# Section
# City-wide GHG Emissions Data                      0.201373
# Transport                                         0.120517
# Climate Hazards                                   0.088154
# Mitigation Actions                                0.082873
# Mitigation Target setting                         0.062985
# Adaptation Actions                                0.062069
# Energy                                            0.036829
# GCoM Emission Factor and Activity Data            0.034272
# Finance and Economic Opportunities                0.030615
# Food                                              0.026695
# Buildings                                         0.025445
# Local Government Operations GHG Emissions Data    0.022596
# Governance                                        0.021113
# Waste                                             0.020184
# Adaptation Planning                               0.018977
# Climate Risk and Vulnerability Assessment         0.018209
# ...

# %%
cities.columns
# Out:
# Index(['Unnamed: 0', 'Questionnaire', 'Year Reported to CDP', 'Account Number',
#        'Organization', 'Country', 'CDP Region', 'Parent Section', 'Section',
#        'Question Number', 'Question Name', 'Column Number', 'Column Name',
#        'Row Number', 'Row Name', 'Response Answer', 'Comments', 'File Name',
#        'Last update'],
#       dtype='object')

# %%
water = pd.read_csv('2019_Full_Water_Security_Dataset.csv')
water.head()
# Out:
# /var/folders/5l/vsm1wvjn4qdg25qwjfcj83kr0000gn/T/ipykernel_25991/555433020.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   water = pd.read_csv('2019_Full_Water_Security_Dataset.csv')
#    Unnamed: 0  account_number organization  survey_year  \
# 0           0           20111  Vander Bend         2019
# 1           1           20111  Vander Bend         2019
# 2           2           20111  Vander Bend         2019
# 3           3           20111  Vander Bend         2019
# 4           4           20111  Vander Bend         2019
#
#   response_received_date  accounting_period_to  ors_response_id  \
# 0   2019-07-18T16:12:55Z                   NaN            60218
# 1   2019-07-18T16:12:55Z                   NaN            60218
# 2   2019-07-18T16:12:55Z                   NaN            60218
# 3   2019-07-18T16:12:55Z                   NaN            60218
# 4   2019-07-18T16:12:55Z                   NaN            60218
# ...

# %%
water.columns
# Out:
# Index(['Unnamed: 0', 'account_number', 'organization', 'survey_year',
#        'response_received_date', 'accounting_period_to', 'ors_response_id',
#        'submission_date', 'page_name', 'module_name', 'question_number',
#        'question_unique_reference', 'column_number', 'column_name',
#        'table_columns_unique_reference', 'row_number', 'row_name',
#        'data_point_name', 'data_point_id', 'response_value', 'comments'],
#       dtype='object')

# %%
public_data = pd.read_csv('NA_HQ_public_data.csv')
public_data.head()
# Out:
#    Unnamed: 0  account_number                        organization  public  \
# 0           0           58859  Hewlett Packard Enterprise Company  public
# 1           1           31831             Bausch Health Cos. Inc.  public
# 2           2           40952                           BWI Group  public
# 3           3           30634                  Guangdong Textiles  public
# 4           4           19582  Johnson Controls International PLC  public
#
#   invitation_status request_status           theme  survey_year  \
# 0         Submitted      Submitted  Climate Change         2020
# 1         Submitted      Submitted  Climate Change         2020
# 2         Submitted      Submitted  Climate Change         2020
# 3         Submitted      Submitted  Climate Change         2020
# 4         Submitted      Submitted  Climate Change         2020
#
#            survey_name                hq_country address_city address_state  \
# ...

# %%
public_data['theme'].value_counts(normalize=True)
# Out:
# theme
# Climate Change    0.768415
# Water             0.231585
# Name: proportion, dtype: float64

# %%
public_data.columns
# Out:
# Index(['Unnamed: 0', 'account_number', 'organization', 'public',
#        'invitation_status', 'request_status', 'theme', 'survey_year',
#        'survey_name', 'hq_country', 'address_city', 'address_state',
#        'address_lat', 'adress_long'],
#       dtype='object')

# %%
social_vulnerability = pd.read_csv('SVI2018_US.csv')
social_vulnerability.head()
# Out:
#    Unnamed: 0  ST    STATE ST_ABBR  STCNTY   COUNTY        FIPS  \
# 0           0   1  ALABAMA      AL    1015  Calhoun  1015981901
# 1           1   1  ALABAMA      AL    1015  Calhoun  1015981902
# 2           2   1  ALABAMA      AL    1015  Calhoun  1015981903
# 3           3   1  ALABAMA      AL    1097   Mobile  1097003605
# 4           4   1  ALABAMA      AL    1097   Mobile  1097990000
#
#                                         LOCATION  AREA_SQMI  E_TOTPOP  ...  \
# 0  Census Tract 9819.01, Calhoun County, Alabama  24.243865         0  ...
# 1  Census Tract 9819.02, Calhoun County, Alabama  34.646714         0  ...
# 2  Census Tract 9819.03, Calhoun County, Alabama  13.926276         0  ...
# 3     Census Tract 36.05, Mobile County, Alabama   0.732300       899  ...
# 4      Census Tract 9900, Mobile County, Alabama   0.000000         0  ...
#
#    F_CROWD  F_NOVEH  F_GROUPQ  F_THEME4  F_TOTAL  E_UNINSUR  M_UNINSUR  \
# ...

# %%
list(social_vulnerability.columns)
# Out:
# ['Unnamed: 0',
#  'ST',
#  'STATE',
#  'ST_ABBR',
#  'STCNTY',
#  'COUNTY',
#  'FIPS',
#  'LOCATION',
#  'AREA_SQMI',
#  'E_TOTPOP',
#  'M_TOTPOP',
#  'E_HU',
#  'M_HU',
#  'E_HH',
#  'M_HH',
#  'E_POV',
#  'M_POV',
#  'E_UNEMP',
#  'M_UNEMP',
#  'E_PCI',
#  'M_PCI',
#  'E_NOHSDP',
#  'M_NOHSDP',
#  'E_AGE65',
#  'M_AGE65',
#  'E_AGE17',
#  'M_AGE17',
#  'E_DISABL',
#  'M_DISABL',
#  'E_SNGPNT',
#  'M_SNGPNT',
#  'E_MINRTY',
#  'M_MINRTY',
#  'E_LIMENG',
#  'M_LIMENG',
#  'E_MUNIT',
#  'M_MUNIT',
#  'E_MOBILE',
#  'M_MOBILE',
#  'E_CROWD',
#  'M_CROWD',
#  'E_NOVEH',
#  'M_NOVEH',
#  'E_GROUPQ',
#  'M_GROUPQ',
#  'EP_POV',
#  'MP_POV',
#  'EP_UNEMP',
#  'MP_UNEMP',
#  'EP_PCI',
#  'MP_PCI',
#  'EP_NOHSDP',
#  'MP_NOHSDP',
#  'EP_AGE65',
#  'MP_AGE65',
#  'EP_AGE17',
#  'MP_AGE17',
#  'EP_DISABL',
#  'MP_DISABL',
#  'EP_SNGPNT',
#  'MP_SNGPNT',
#  'EP_MINRTY',
#  'MP_MINRTY',
#  'EP_LIMENG',
#  'MP_LIMENG',
#  'EP_MUNIT',
#  'MP_MUNIT',
#  'EP_MOBILE',
#  'MP_MOBILE',
#  'EP_CROWD',
# ...

# %%
social_vulnerability.head()
# Out:
#    Unnamed: 0  ST    STATE ST_ABBR  STCNTY   COUNTY        FIPS  \
# 0           0   1  ALABAMA      AL    1015  Calhoun  1015981901
# 1           1   1  ALABAMA      AL    1015  Calhoun  1015981902
# 2           2   1  ALABAMA      AL    1015  Calhoun  1015981903
# 3           3   1  ALABAMA      AL    1097   Mobile  1097003605
# 4           4   1  ALABAMA      AL    1097   Mobile  1097990000
#
#                                         LOCATION  AREA_SQMI  E_TOTPOP  ...  \
# 0  Census Tract 9819.01, Calhoun County, Alabama  24.243865         0  ...
# 1  Census Tract 9819.02, Calhoun County, Alabama  34.646714         0  ...
# 2  Census Tract 9819.03, Calhoun County, Alabama  13.926276         0  ...
# 3     Census Tract 36.05, Mobile County, Alabama   0.732300       899  ...
# 4      Census Tract 9900, Mobile County, Alabama   0.000000         0  ...
#
#    F_CROWD  F_NOVEH  F_GROUPQ  F_THEME4  F_TOTAL  E_UNINSUR  M_UNINSUR  \
# ...

# %%
us_cities = pd.read_csv('uscities.csv')
us_cities.head()
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     New York     New York       NY    New York        36081       Queens
# 1  Los Angeles  Los Angeles       CA  California         6037  Los Angeles
# 2      Chicago      Chicago       IL    Illinois        17031         Cook
# 3        Miami        Miami       FL     Florida        12086   Miami-Dade
# 4      Houston      Houston       TX       Texas        48201       Harris
#
#        lat       lng  population  density source  military  incorporated  \
# 0  40.6943  -73.9249    18908608  11080.3  shape     False          True
# 1  34.1141 -118.4068    11922389   3184.7  shape     False          True
# 2  41.8375  -87.6866     8497759   4614.5  shape     False          True
# 3  25.7840  -80.2101     6080145   4758.9  shape     False          True
# 4  29.7860  -95.3885     5970127   1384.0  shape     False          True
#
#               timezone  ranking  \
# 0     America/New_York        1
# ...

# %%
us_cities.columns
# Out:
# Index(['city', 'city_ascii', 'state_id', 'state_name', 'county_fips',
#        'county_name', 'lat', 'lng', 'population', 'density', 'source',
#        'military', 'incorporated', 'timezone', 'ranking', 'zips', 'id'],
#       dtype='object')
